# %% [markdown]
# # Get Youtube Channel Id from Youtube Channel url

# %%
# Import the required modules
import requests
import pandas as pd
import re
# Get channel_id from channel_name of youtuber
def get_channelId(channel_link):

    # Get the HTML content of the channel page
    response = requests.get(channel_link).text

    # Find the canonical link tag in the HTML using a regular expression
    match = re.search(r'<link rel="canonical" href="https://www.youtube.com/channel/(.+?)"', response)

    # Check if a match was found
    if match:
        # Extract the channel ID from the match group
        channel_id = match.group(1)
        # Print the channel ID
        print(f"The channel ID for {channel_link} is {channel_id}")
        return channel_id
    else:
        # Print an error message
        print(f"No channel ID found for {channel_link}")
        return ''

# %% [markdown]
# # Iterate over all youtube videos for a specific channel
#
# > Indented block

# %%
import requests
import pandas as pd

def allVideos(channelurl):
    # Insert youtube channel video url here...
    channel_id = get_channelId(channelurl)
    print(channel_id)
    api_key = "AIzaSyB5Jjb5Nl_I0GIpa1-wSmTkjaM0I1Vi8iU"  # Replace with your own API key

    # Initialize an empty list to store DataFrames
    df_list = []

    # Make the first request to get the initial results and the total number of results
    url = f"https://youtube.googleapis.com/youtube/v3/search?part=snippet&channelId={channel_id}&maxResults=50&order=date&type=video&key={api_key}"
    response = requests.get(url=url).json()
    total_results = response["pageInfo"]["totalResults"]

    # Loop through the response items and append them to the list
    for i in response["items"]:
        channel_id = i["snippet"]["channelId"]
        video_id = 'https://www.youtube.com/watch?v=' + i["id"]["videoId"]
        video_title = i["snippet"]["title"]
        published_date = i["snippet"]["publishedAt"]
        vid_type = i["id"]["kind"]
        row_data = {"channel_id": channel_id, "video_id": video_id, "video_title": video_title, "published_date": published_date, "type": vid_type}
        df_list.append(pd.DataFrame([row_data]))

    # If there are more than 50 results, use the nextPageToken to get the next page of results
    if "nextPageToken" in response:
        page_token = response["nextPageToken"]
    else:
        page_token = None

    # Loop until there are no more pages of results
    while page_token is not None:
        # Make the next request with the page token
        url = f"https://youtube.googleapis.com/youtube/v3/search?part=snippet&channelId={channel_id}&maxResults=50&order=date&type=video&pageToken={page_token}&key={api_key}"
        response = requests.get(url=url).json()
        # Update the page token
        if "nextPageToken" in response:
            page_token = response["nextPageToken"]
        else:
            page_token = None
        # Loop through the response items and append them to the list
        for i in response["items"]:
            channel_id = i["snippet"]["channelId"]
            video_id = 'https://www.youtube.com/watch?v=' + i["id"]["videoId"]
            video_title = i["snippet"]["title"]
            published_date = i["snippet"]["publishedAt"]
            vid_type = i["id"]["kind"]
            row_data = {"channel_id": channel_id, "video_id": video_id, "video_title": video_title, "published_date": published_date, "type": vid_type}
            df_list.append(pd.DataFrame([row_data]))

    # Concatenate all DataFrames in the list into one DataFrame
    df = pd.concat(df_list, ignore_index=True)

    # Save the DataFrame as a CSV file
    df.to_csv("video_ids.csv", index=False)

# Define your get_channelId function here if it's not already defined

# %% [markdown]
# # Create a GUI interface to interact with user for getting youtube channel as input

# %%
# !pip install ipywidgets
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

def f(youtube_channel_link):
    return allVideos(youtube_channel_link)

interact(f, youtube_channel_link='Placeholder link');#https://www.youtube.com/@GrahamStephan/videos or https://www.youtube.com/@SandeepSeminars/videos
# Out:
# Requirement already satisfied: ipywidgets in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (8.19.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: decorator in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# interactive(children=(Text(value='Placeholder link', description='youtube_channel_link'), Output()), _dom_clas…

# %% [markdown]
# # Using Langchain to summarize/ do question answering

# %%
! pip install yt_dlp
! pip install pydub
! pip install langchain
# If Visual C++ tools don't exist add them..
# Out:
# Requirement already satisfied: yt_dlp in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (2023.12.30)
# Requirement already satisfied: mutagen in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from yt_dlp) (1.47.0)
# Requirement already satisfied: pycryptodomex in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from yt_dlp) (3.19.1)
# Requirement already satisfied: certifi in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from yt_dlp) (2023.11.17)
# Requirement already satisfied: requests<3,>=2.31.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from yt_dlp) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.26.17 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from yt_dlp) (2.1.0)
# Requirement already satisfied: websockets>=12.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from yt_dlp) (12.0)
# Requirement already satisfied: brotli in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from yt_dlp) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.31.0->yt_dlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.31.0->yt_dlp) (3.6)
# Requirement already satisfied: pydub in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (0.25.1)
# Requirement already satisfied: langchain in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (0.1.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (3.9.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.9 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.0.9)
# Requirement already satisfied: langchain-core<0.2,>=0.1.7 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.1.7)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.77 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.0.77)
# Requirement already satisfied: numpy<2,>=1 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (1.26.3)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.5.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2,>=0.1.7->langchain) (4.2.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2,>=0.1.7->langchain) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.7->langchain) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)

# %%
# ! pip install yt_dlp
# ! pip install pydub
# !pip install openai
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import OpenAIWhisperParser
from langchain.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader
# Out:
# Collecting openai
#   Downloading openai-1.6.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.2.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.5.3)
# Requirement already satisfied: sniffio in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: certifi in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.2-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)
# Requirement already satisfied: colorama in c:\users\shiva\appdata\local\programs\python\python312\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.6.1-py3-none-any.whl (225 kB)
#    ---------------------------------------- 0.0/225.4 kB ? eta -:--:--
#    ---------------------------------------- 225.4/225.4 kB 6.9 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.9 kB ? eta -:--:--
#    ---------------------------------------- 75.9/75.9 kB 4.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.9 kB ? eta -:--:--
#    ---------------------------------------- 76.9/76.9 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: h11, distro, httpcore, httpx, openai
# Successfully installed distro-1.9.0 h11-0.14.0 httpcore-1.0.2 httpx-0.26.0 openai-1.6.1

# %% [markdown]
# # Transcribe the videos from youtuber example

# %%
import os
import yt_dlp

os.environ['OPENAI_API_KEY'] = '';
urls = 'https://www.youtube.com/watch?v=p7iwXvBnbIE'
save_dir = "docs/youtube/"

loader = GenericLoader(
    YoutubeAudioLoader([urls], save_dir),
    OpenAIWhisperParser()
)
docs = loader.load()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=p7iwXvBnbIE
# [youtube] p7iwXvBnbIE: Downloading webpage
# [youtube] p7iwXvBnbIE: Downloading ios player API JSON
# [youtube] p7iwXvBnbIE: Downloading android player API JSON
# [youtube] p7iwXvBnbIE: Downloading m3u8 information
# [info] p7iwXvBnbIE: Downloading 1 format(s): 140
# [download] docs\youtube\Take a Seat in the Harvard MBA Case Classroom.m4a has already been downloaded
# [download] 100% of    9.25MiB
# [ExtractAudio] Not converting audio docs\youtube\Take a Seat in the Harvard MBA Case Classroom.m4a; file is already in target format m4a
# Transcribing part 1!
# Attempt 1 failed. Exception: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# Attempt 2 failed. Exception: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# Attempt 3 failed. Exception: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# Failed to transcribe after 3 attempts.

# %% [markdown]
# # Summarize all YouTuber videos and save those in database or csv

# %%
import pandas as pd
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import OpenAIWhisperParser
from langchain.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader
import traceback

# Define the URL of the video you want to download
video_url = "https://www.youtube.com/watch?v=jGwO_UgTS7I"

# Read the video URLs from a CSV file (assuming a 'video_id' column in the CSV)
csv_file = "video_ids.csv"
youtube_videos = pd.read_csv(csv_file)
video_urls = youtube_videos["video_id"]

print(video_urls)
# Define the directory where you want to save the downloaded audio
save_dir = "docs/youtube/"

# Initialize the loader
loader = GenericLoader(
    YoutubeAudioLoader(video_urls.tolist(), save_dir),
    OpenAIWhisperParser()
)

# Iterate through video URLs and handle exceptions
for url in video_urls:
    try:
        # Create a list with the current URL for processing
        current_urls = [url]

        # Use the loader to process the current URL
        loader = GenericLoader(
            YoutubeAudioLoader(current_urls, save_dir),
            OpenAIWhisperParser()
        )
        docs = loader.load()

        # You can process 'docs' as needed here
        # ...

    except Exception as e:
        print(f"Error processing URL: {url}")
        traceback.print_exc()

# Continue processing other URLs, even if some fail

# %% [markdown]
# # Create a question-answering system for users to quickly access required information from their favorite youtuber.
